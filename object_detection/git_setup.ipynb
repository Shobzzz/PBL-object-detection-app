# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive

# %%
from getpass import getpass

token = getpass("GitHub Token:")

# %%
repo = f"https://{token}@github.com/Shobzzz/PBL-object-detection-app.git"
# !git clone $repo
