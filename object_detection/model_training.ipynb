# %%
# Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/PBL-object-detection-app/object_detection/
# !git pull
# Out:
# /content/drive/MyDrive/PBL-object-detection-app/object_detection
# Already up to date.

# %%
# 必要なライブラリのインストール
# !pip install ultralytics
# !pip install -q roboflow

# %%
#テスト用
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="psQg1UFSUlfkGUyi1PgA")
project = rf.workspace("kentas-workspace-3yhy5").project("buoy-ball-wntyt")
dataset = project.version(1).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Buoy-Ball-1 in yolov8:: 100%|██████████| 290/290 [00:02<00:00, 105.21it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  #モデル

results = model.train(
    data=f"{dataset.location}/data.yaml",
    # data="/content/drive/MyDrive/PBL-object-detection-app/object_detection/dataset-white/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    device=0,
    workers=4,
    patience=20,
    lr0=0.01,
    augment=True,
    cache=False,
    project="runs/detect",
    name="buoy_detection_v1",
    exist_ok=True,
)

print(f"Best weights saved at: {results.save_dir}/weights/best.pt")
# Out:
# Ultralytics 8.4.61 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !git add .
# !git commit -m "Update YOLO training settings"
# !git push origin main
# Out:
# [main 9a182f1] Update YOLO training settings
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 857 bytes | 171.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/Shobzzz/PBL-object-detection-app.git
#    1d3653f..9a182f1  main -> main
